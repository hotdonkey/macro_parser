# %%
import pandas as pd
import gspread
from df2gspread import df2gspread as d2g
from oauth2client.service_account import ServiceAccountCredentials

# %%
#First step to connect to google docs api
scope = [
    'https://spreadsheets.google.com/feeds',
    'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name(
    'macro-parser-lme-91426ddd21e1.json', scope)
gc = gspread.authorize(credentials)

#Create df from excel that we want to upload
df_LME = pd.read_excel('/Users/hotdonkey/Documents/GitHub/data_science_learning/code/LME/parser_beta/data/LME_db.xlsx')
df_KITCO = pd.read_excel('/Users/hotdonkey/Documents/GitHub/data_science_learning/code/LME/parser_beta/data/kitko_db.xlsx')
df_cb_curr = pd.read_excel('/Users/hotdonkey/Documents/GitHub/data_science_learning/code/LME/parser_beta/data/cb_curr.xlsx')
df_cb_metall = pd.read_excel('/Users/hotdonkey/Documents/GitHub/data_science_learning/code/LME/parser_beta/data/cb_metall.xlsx')

#Drop index column
df_LME.drop(['Unnamed: 0'], axis=1, inplace=True)
df_KITCO.drop(['Unnamed: 0'], axis=1, inplace=True)
df_cb_curr.drop(['Unnamed: 0'], axis=1, inplace=True)
df_cb_metall.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
#Second step and final step
spreadsheet_key = '1WhLiXRcdlkG7NCvHac9unC8ROt4lcbY7GxrOEdezZ9s'
wks_name = 'LME_non_ferrous'
d2g.upload(df_LME, spreadsheet_key, wks_name, credentials=credentials)

wks_name = 'KITCO'
d2g.upload(df_KITCO, spreadsheet_key, wks_name, credentials=credentials)

wks_name = 'cb_curr'
d2g.upload(df_cb_curr, spreadsheet_key, wks_name, credentials=credentials)

wks_name = 'cb_metall'
d2g.upload(df_cb_metall, spreadsheet_key, wks_name, credentials=credentials)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/gspread/spreadsheet.py:335, in Spreadsheet.worksheet(self, title)
#     334 try:
# --> 335     item = finditem(
#     336         lambda x: x["properties"]["title"] == title,
#     337         sheet_data["sheets"],
#     338     )
#     339     return Worksheet(self, item["properties"])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/gspread/utils.py:133, in finditem(func, seq)
#     132 """Finds and returns first item in iterable for which func(item) is True."""
# --> 133 return next(item for item in seq if func(item))
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# WorksheetNotFound                         Traceback (most recent call last)
# ...

# %%
currency_df = pd.read_excel(
        '/Users/hotdonkey/Documents/GitHub/data_science_learning/code/LME/parser_beta/data/cb_curr.xlsx', index_col=0)

# %%
currency_df
# Out:
#          Date                 Id  Nominal    Value
# 0  2022-12-28                USD        1  69.9346
# 1  2022-12-28                EUR        1  74.1829
# 2  2022-12-28  Australian_Dollar        1  46.7163
# 3  2022-12-28         China_Yuan       10  99.4575
# 4  2022-12-28      British_Pound        1  84.1313
# 5  2022-12-28   Kazakhstan_Tenge      100  15.1669
# 6  2022-12-28       Japanese_Yen     1000  55.0060
# 7  2022-12-28        Swiss_Franc        1  75.3119
# 8  2022-12-29                USD        1  71.3261
# 9  2022-12-29                EUR        1  75.6600
# 10 2022-12-29  Australian_Dollar        1  48.0809
# 11 2022-12-29         China_Yuan        1  10.1469
# 12 2022-12-29      British_Pound        1  85.8053
# 13 2022-12-29   Kazakhstan_Tenge      100  15.4848
# 14 2022-12-29       Japanese_Yen     1000  56.2953
# 15 2022-12-29        Swiss_Franc        1  76.6782
# 16 2022-12-30                USD        1  71.9778
# ...
